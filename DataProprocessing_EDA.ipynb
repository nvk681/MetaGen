# %% [markdown]
# <a href="https://colab.research.google.com/github/nvk681/MetaGen/blob/main/DataProprocessing_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing all the required libraries
# !pip install wordcloud
# !pip install gtts
# !pip install playsound

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

import tensorflow as tf
import keras
from keras.preprocessing.image import load_img
import string
import time
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer

from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras import layers
from tensorflow.keras import activations
from tensorflow.keras import Input
from PIL import Image
#used for creating Progress Meters or Progress Bars
from tqdm import tqdm
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.7/dist-packages (1.5.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from wordcloud) (7.1.2)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from wordcloud) (1.21.5)
# Collecting gtts
#   Downloading gTTS-2.2.4-py3-none-any.whl (26 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from gtts) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from gtts) (2.23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gtts) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->gtts) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->gtts) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->gtts) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->gtts) (2.10)
# Installing collected packages: gtts
# Successfully installed gtts-2.2.4
# Collecting playsound
#   Downloading playsound-1.3.0.tar.gz (7.7 kB)
# Building wheels for collected packages: playsound
#   Building wheel for playsound (setup.py) ... done
#   Created wheel for playsound: filename=playsound-1.3.0-py3-none-any.whl size=7035 sha256=b3a227fa9c517bf7a87f6c00eaa775917d4bdaba7ca2d84e565d256af7a3e62f
#   Stored in directory: /root/.cache/pip/wheels/ba/f8/bb/ea57c0146b664dca3a0ada4199b0ecb5f9dfcb7b7e22b65ba2
# Successfully built playsound
# Installing collected packages: playsound
# Successfully installed playsound-1.3.0

# %%
import glob
from gtts import gTTS
from playsound import playsound
from IPython import display
import collections
import wordcloud
from wordcloud import WordCloud, STOPWORDS
# Out:
# playsound is relying on another python subprocess. Please use `pip install pygobject` if you want playsound to run more efficiently.

# %%
import numpy as np 
import pandas as pd 
import os
for dirname, _, filenames in os.walk('drive/MyDrive/dataset/'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
# %cd drive/MyDrive/dataset/
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/dataset/'
# /content/drive/.shortcut-targets-by-id/1EX2CiJz1QtnETfBBJn0ScGddMmDgTD7O/dataset

# %% [markdown]
# ## Exploratory Data Analysis

# %%
images='Flickr8k/Flickr8k/Images'
all_imgs = glob.glob(images + '/*.jpg',recursive=True)
print("The total images present in the dataset: {}".format(len(all_imgs)))
# Out:
# The total images present in the dataset: 8091

# %%
import imageio
#Visualising first 5 images :
Display_Images = all_imgs[0:5]
figure, axes = plt.subplots(1,5)
figure.set_figwidth(20)
for ax, image in zip(axes, Display_Images):
  ax.imshow(imageio.imread(image), cmap=None)

# %%
import random
Image.open(all_imgs[random.randrange(40, 60, 3)])# view a random image
import random
Image.open(all_imgs[random.randrange(40, 60, 3)])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x384 at 0x7FA165CDAC90>

# %%
text_file = 'Flickr8k/Flickr8k/captions.txt'
def load_doc(filename):
    open_file = open(text_file, 'r', encoding='latin-1' ) 
    text = open_file.read() 
    open_file.close()
    return text
doc = load_doc(text_file)
print(doc[:300])
# Out:
# image,caption
# 1000268201_693b08cb0e.jpg,A child in a pink dress is climbing up a set of stairs in an entry way .
# 1000268201_693b08cb0e.jpg,A girl going into a wooden building .
# 1000268201_693b08cb0e.jpg,A little girl climbing into a wooden playhouse .
# 1000268201_693b08cb0e.jpg,A little girl climbing

# %%
img_path = 'Flickr8k/Flickr8k/Images/'

all_img_id = [] 
all_img_vector = [] 
annotations = [] 

with open('Flickr8k/Flickr8k/captions.txt' , 'r') as fo:
  next(fo) 
  for line in fo :
    split_arr = line.split(',')
    all_img_id.append(split_arr[0])
    annotations.append(split_arr[1].rstrip('\n.')) #removing out the \n.
    all_img_vector.append(img_path+split_arr[0])

df = pd.DataFrame(list(zip(all_img_id, all_img_vector,annotations)),columns =['ID','Path', 'Captions']) 
    
df
# Out:
#                               ID  \
# 0      1000268201_693b08cb0e.jpg
# 1      1000268201_693b08cb0e.jpg
# 2      1000268201_693b08cb0e.jpg
# 3      1000268201_693b08cb0e.jpg
# 4      1000268201_693b08cb0e.jpg
# ...                          ...
# 40450   997722733_0cb5439472.jpg
# 40451   997722733_0cb5439472.jpg
# 40452   997722733_0cb5439472.jpg
# 40453   997722733_0cb5439472.jpg
# 40454   997722733_0cb5439472.jpg
#
#                                                     Path  \
# 0      Flickr8k/Flickr8k/Images/1000268201_693b08cb0e...
# 1      Flickr8k/Flickr8k/Images/1000268201_693b08cb0e...
# 2      Flickr8k/Flickr8k/Images/1000268201_693b08cb0e...
# 3      Flickr8k/Flickr8k/Images/1000268201_693b08cb0e...
# 4      Flickr8k/Flickr8k/Images/1000268201_693b08cb0e...
# ...                                                  ...
# 40450  Flickr8k/Flickr8k/Images/997722733_0cb5439472.jpg
# 40451  Flickr8k/Flickr8k/Images/997722733_0cb5439472.jpg
# 40452  Flickr8k/Flickr8k/Images/997722733_0cb5439472.jpg
# 40453  Flickr8k/Flickr8k/Images/997722733_0cb5439472.jpg
# 40454  Flickr8k/Flickr8k/Images/997722733_0cb5439472.jpg
#
#                                                 Captions
# 0      A child in a pink dress is climbing up a set o...
# 1                   A girl going into a wooden building
# 2        A little girl climbing into a wooden playhouse
# 3      A little girl climbing the stairs to her playh...
# 4      A little girl in a pink dress going into a woo...
# ...                                                  ...
# 40450           A man in a pink shirt climbs a rock face
# 40451            A man is rock climbing high in the air
# 40452  A person in a red shirt climbing up a rock fac...
# 40453                     A rock climber in a red shirt
# 40454  A rock climber practices on a rock climbing wall
#
# [40455 rows x 3 columns]

# %%
#check total captions and images present in dataset
print("Total captions present in the dataset: "+ str(len(annotations)))
print("Total images present in the dataset: " + str(len(all_imgs)))
# Out:
# Total captions present in the dataset: 40455
# Total images present in the dataset: 8091

# %%
#Create the vocabulary & the counter for the captions
vocabulary = [word.lower() for line in annotations for word in line.split()]
val_count = Counter(vocabulary) 
val_count
# Out:
# Counter({'a': 60196,
#          'child': 1507,
#          'in': 18174,
#          'pink': 702,
#          'dress': 332,
#          'is': 9069,
#          'climbing': 490,
#          'up': 1215,
#          'set': 105,
#          'of': 6495,
#          'stairs': 109,
#          'an': 2325,
#          'entry': 1,
#          'way': 48,
#          'girl': 3277,
#          'going': 145,
#          'into': 1046,
#          'wooden': 278,
#          'building': 485,
#          'little': 1736,
#          'playhouse': 6,
#          'the': 17507,
#          'to': 3005,
#          'her': 1102,
#          'cabin': 4,
#          'black': 3620,
#          'dog': 7948,
#          'and': 8057,
#          'spotted': 36,
#          'are': 3365,
#          'fighting': 130,
#          'tri-colored': 12,
#          'playing': 1954,
#          'with': 7304,
#          'each': 399,
#          'other': 667,
#          'on': 10357,
#          'road': 380,
#          'white': 3706,
#          'brown': 2457,
#          'spots': 28,
#          'staring': 57,
#          'at': 2810,
#          'street': 908,
#          'two': 5132,
#          'dogs': 2095,
#          'different': 43,
#          'breeds': 5,
#          'looking': 682,
#          'pavement': 46,
#          'moving': 40,
#          'toward': 142,
#          'covered': 286,
#          'paint': 57,
#          'sits': 561,
#          'front': 1322,
#          'painted': 62,
#          'rainbow': 17,
#          'hands': 231,
#          'bowl': 29,
#          'sitting': 1322,
#          'large': 1207,
#          'small': 1257,
#          'grass': 1565,
#          'plays': 515,
#          'fingerpaints': 3,
#          'canvas': 6,
#          'it': 370,
#          'there': 253,
#          'pigtails': 14,
#          'painting': 43,
#          'young': 2587,
#          'outside': 756,
#          'man': 7137,
#          'lays': 55,
#          'bench': 360,
#          'while': 1807,
#          'his': 2255,
#          'by': 1167,
#          'him': 353,
#          'which': 27,
#          'also': 15,
#          'tied': 13,
#          'sleeping': 58,
#          'next': 714,
#          'shirtless': 99,
#          'lies': 43,
#          'park': 487,
#          'laying': 181,
#          'holding': 1211,
#          'leash': 125,
#          'ground': 332,
#          'orange': 694,
#          'hat': 633,
#          'starring': 8,
#          'something': 329,
#          'wears': 111,
#          'glasses': 184,
#          'gauges': 2,
#          'wearing': 2916,
#          'blitz': 1,
#          'beer': 43,
#          'can': 37,
#          'crocheted': 1,
#          'pierced': 6,
#          'ears': 65,
#          'rope': 237,
#          'net': 57,
#          'red': 2553,
#          'roping': 2,
#          'climbs': 197,
#          'bridge': 135,
#          'grips': 2,
#          'onto': 204,
#          'ropes': 37,
#          'playground': 198,
#          'running': 1996,
#          'grassy': 446,
#          'garden': 51,
#          'surrounded': 155,
#          'fence': 319,
#          'through': 1978,
#          'boston': 9,
#          'terrier': 30,
#          'lush': 8,
#          'green': 1156,
#          'runs': 906,
#          'near': 959,
#          '"a': 1234,
#          'shakes': 36,
#          'its': 863,
#          'head': 358,
#          'shore': 157,
#          'edge': 165,
#          'beach': 1018,
#          'ball': 1678,
#          '"dog': 8,
#          'feet': 79,
#          'water': 2676,
#          'standing': 1702,
#          'turned': 17,
#          'one': 751,
#          'side': 286,
#          'boy': 3514,
#          'smiles': 183,
#          'stony': 3,
#          'wall': 533,
#          'city': 309,
#          'overalls': 22,
#          'working': 23,
#          'stone': 123,
#          'aross': 1,
#          'walking': 1126,
#          'paved': 41,
#          'metal': 110,
#          'pole': 151,
#          'behind': 552,
#          'smiling': 434,
#          'shirt': 1735,
#          'blue': 2125,
#          'jeans': 207,
#          'rock': 730,
#          'leaps': 200,
#          'over': 1378,
#          'log': 53,
#          'grey': 232,
#          'leaping': 129,
#          'fallen': 67,
#          'tree': 390,
#          'mottled': 2,
#          'collar': 193,
#          'jumping': 1430,
#          'jumped': 33,
#          'stump': 27,
#          'snow': 1439,
#          'field': 1221,
#          'surface': 60,
#          'displaying': 5,
#          'pictures': 63,
#          'skier': 179,
#          'skis': 81,
#          'past': 145,
#          'another': 893,
#          'paintings': 4,
#          'person': 1515,
#          'framed': 7,
#          'looks': 490,
#          'trees': 247,
#          'artwork': 4,
#          'for': 901,
#          'sale': 7,
#          'collage': 2,
#          'cliff': 194,
#          'group': 1200,
#          'people': 2811,
#          'belays': 1,
#          'seven': 29,
#          'climbers': 27,
#          'ascending': 8,
#          'face': 445,
#          'whilst': 147,
#          'stands': 841,
#          'several': 297,
#          'row': 34,
#          'watches': 259,
#          'holds': 453,
#          'line': 145,
#          'chases': 97,
#          'from': 866,
#          'sprinkler': 52,
#          'lawn': 110,
#          'hose': 44,
#          'away': 153,
#          'prepares': 48,
#          'catch': 354,
#          'thrown': 44,
#          'object': 146,
#          'nearby': 140,
#          'cars': 61,
#          'about': 142,
#          'yellow': 1148,
#          'mouth': 913,
#          'toy': 549,
#          'ready': 119,
#          'flying': 165,
#          'air': 1008,
#          'after': 176,
#          'get': 100,
#          'jumps': 955,
#          'towards': 234,
#          'trying': 157,
#          'midair': 205,
#          'woman': 3304,
#          'waters': 29,
#          'big': 267,
#          'lake': 318,
#          'lone': 81,
#          'duck': 35,
#          'swimming': 433,
#          'around': 622,
#          'watching': 237,
#          'waves': 134,
#          'hand': 318,
#          '"two': 414,
#          'couple': 243,
#          'infant': 15,
#          'sit': 349,
#          'baby': 409,
#          'stroller': 26,
#          'their': 662,
#          'newborn': 8,
#          'under': 237,
#          'facing': 46,
#          'care': 3,
#          'along': 508,
#          'body': 185,
#          'outdoors': 155,
#          'surf': 72,
#          'lab': 24,
#          'tags': 7,
#          'frolicks': 2,
#          'splashes': 69,
#          'this': 118,
#          'splashing': 125,
#          'drilling': 5,
#          'hole': 35,
#          'ice': 218,
#          'frozen': 25,
#          'pond': 92,
#          'men': 1102,
#          'fishing': 102,
#          'play': 713,
#          'making': 142,
#          'turn': 69,
#          'soft': 13,
#          'sand': 446,
#          'together': 403,
#          'tan': 380,
#          'sandy': 105,
#          'uses': 26,
#          'picks': 12,
#          'crampons': 1,
#          'scale': 1,
#          'climber': 124,
#          'jacket': 649,
#          'pants': 234,
#          'scaling': 20,
#          'waterfall': 85,
#          'carries': 126,
#          'as': 841,
#          'he': 203,
#          'walks': 531,
#          'carrying': 396,
#          'has': 519,
#          'item': 18,
#          'wet': 169,
#          'kayak': 87,
#          'life': 82,
#          'jackets': 67,
#          'rowing': 33,
#          'canoe': 71,
#          'gentle': 1,
#          'ride': 248,
#          'courtyard': 28,
#          'catching': 106,
#          'snaps': 1,
#          'lunges': 6,
#          'chocolate': 13,
#          'too': 6,
#          'late': 3,
#          'captures': 1,
#          'driveway': 13,
#          'stick': 437,
#          'kneeling': 33,
#          'goalie': 42,
#          'hockey': 194,
#          'guarding': 9,
#          'goal': 81,
#          'kid': 182,
#          'rink': 30,
#          'male': 110,
#          'right': 85,
#          '"hockey': 1,
#          'crouches': 28,
#          'modern': 5,
#          'art': 38,
#          'structure': 73,
#          'glass': 59,
#          'reads': 46,
#          'newspaper': 34,
#          'sculpture': 22,
#          'office': 11,
#          'statue': 60,
#          'backpack': 145,
#          'buildings': 66,
#          'reading': 84,
#          'tent': 79,
#          'being': 326,
#          'enter': 8,
#          'setting': 78,
#          'hut': 12,
#          'iced': 3,
#          'snowy': 402,
#          'three': 1251,
#          'hill': 429,
#          'sky': 129,
#          'them': 216,
#          'stand': 498,
#          'kneels': 26,
#          'skyscraper': 6,
#          'very': 159,
#          'tall': 139,
#          'distance': 99,
#          'camera': 657,
#          'bites': 31,
#          'hard': 16,
#          'treat': 16,
#          'biting': 79,
#          'baked': 2,
#          'good': 7,
#          'putting': 32,
#          'both': 66,
#          'eats': 52,
#          'food': 83,
#          'table': 246,
#          'eating': 141,
#          'pizza': 10,
#          'tin': 1,
#          'dish': 10,
#          'mountainside': 25,
#          'check': 6,
#          'out': 705,
#          'view': 84,
#          'hilltop': 2,
#          'overlooking': 99,
#          'valley': 21,
#          'hang': 32,
#          'top': 463,
#          'overlook': 6,
#          'rest': 24,
#          'ledge': 73,
#          'above': 212,
#          'moutains': 1,
#          'down': 1755,
#          'many': 172,
#          'inflatable': 71,
#          'boats': 38,
#          'kayakers': 8,
#          'railing': 112,
#          'rafts': 6,
#          'below': 49,
#          'crowd': 494,
#          'jersey': 104,
#          'pose': 208,
#          'some': 579,
#          'multiracial': 1,
#          'posing': 281,
#          'picture': 407,
#          '"asian': 4,
#          'blond': 181,
#          'guy': 207,
#          'striped': 203,
#          'takeout': 1,
#          'television': 9,
#          'floor': 146,
#          'fast': 52,
#          'meal': 13,
#          'someone': 155,
#          'tv': 9,
#          'teens': 7,
#          'rail': 101,
#          'crowded': 74,
#          'takes': 166,
#          'jump': 394,
#          'skateboard': 426,
#          'performing': 195,
#          'trick': 375,
#          'leans': 57,
#          'skateboarder': 313,
#          'doing': 417,
#          'board': 129,
#          'platform': 48,
#          'skateboarders': 11,
#          'paddling': 47,
#          'river': 229,
#          'kayaking': 29,
#          'paddles': 33,
#          'boat': 265,
#          'paddle': 40,
#          'shallow': 128,
#          'girls': 832,
#          'ocean': 447,
#          'four': 459,
#          'children': 1135,
#          'pajamas': 18,
#          'have': 73,
#          'pillow': 15,
#          'fight': 76,
#          'kids': 337,
#          'pillow-fight': 1,
#          'bed': 153,
#          'having': 46,
#          'constructions': 1,
#          'workers': 18,
#          'beam': 20,
#          'taking': 195,
#          'break': 31,
#          'construction': 30,
#          'i-beam': 1,
#          'take': 77,
#          'seat': 49,
#          'steel': 4,
#          'boys': 651,
#          'puddle': 93,
#          'balloon': 41,
#          'mud': 111,
#          'sunny': 61,
#          'day': 135,
#          'appears': 31,
#          'wait': 43,
#          'hailing': 1,
#          'taxi': 4,
#          'signaling': 1,
#          'traffic': 46,
#          'blonde': 191,
#          'hair': 382,
#          'tube': 56,
#          'waving': 47,
#          'arm': 138,
#          'oncoming': 1,
#          'brochure': 2,
#          'train': 103,
#          'rides': 451,
#          'magizine': 1,
#          'book': 70,
#          'pamphlet': 1,
#          'rocky': 232,
#          'run': 346,
#          'across': 465,
#          'stones': 9,
#          'area': 362,
#          'background': 442,
#          'descends': 11,
#          'off': 719,
#          'end': 50,
#          'high': 273,
#          'diving': 73,
#          'pool': 679,
#          'dive': 11,
#          'window': 128,
#          'overshirt': 1,
#          'tank': 73,
#          'chrome': 1,
#          'door': 56,
#          'puts': 34,
#          'elevator': 6,
#          'light-colored': 4,
#          'light': 152,
#          'swim': 92,
#          'shorts': 352,
#          'trunks': 95,
#          'arms': 223,
#          'outstretched': 35,
#          'hiker': 80,
#          'bluff': 5,
#          'mountains': 194,
#          'ski': 94,
#          "'s": 379,
#          'landscape': 39,
#          'snow-covered': 47,
#          'mountain': 536,
#          'beautiful': 53,
#          'pauses': 10,
#          'mountaintop': 25,
#          'attempting': 56,
#          'purple': 301,
#          'low': 60,
#          'cut': 26,
#          'yard': 194,
#          'frisbee': 323,
#          'parking': 66,
#          'lot': 103,
#          'middle': 155,
#          'during': 166,
#          'heavy': 25,
#          'mat': 22,
#          'between': 119,
#          'suv': 13,
#          'pickup': 4,
#          'open': 166,
#          'busy': 98,
#          'terrain': 29,
#          'woolly': 1,
#          'doberman': 17,
#          'chasing': 181,
#          'catches': 123,
#          'tennis': 409,
#          'multicolor': 11,
#          'balloons': 25,
#          'night': 154,
#          'hot': 24,
#          'lit': 41,
#          'lined': 35,
#          'nighttime': 12,
#          'helmet': 334,
#          'bike': 841,
#          'miniature': 5,
#          'dirt': 577,
#          'bicycle': 409,
#          'race': 375,
#          'pedals': 3,
#          'quickly': 29,
#          'bmx': 76,
#          'eight': 15,
#          'gathered': 65,
#          'dark': 233,
#          'porch': 24,
#          'darkened': 10,
#          'room': 125,
#          'throwing': 96,
#          'cleans': 2,
#          'bubbles': 89,
#          'suds': 4,
#          'wiped': 2,
#          'clean': 7,
#          'foam': 19,
#          'ramp': 311,
#          'soapy': 1,
#          'getting': 119,
#          'cleaned': 1,
#          'slides': 88,
#          'slide': 293,
#          'wading': 53,
#          'toys': 48,
#          'floating': 37,
#          'backyard': 62,
#          'sliding': 117,
#          'colorful': 210,
#          'tubes': 2,
#          'falling': 74,
#          'colored': 159,
#          'wetsuit': 80,
#          'toddler': 165,
#          'waiting': 111,
#          'come': 11,
#          'so': 14,
#          '"while': 11,
#          'droplets': 6,
#          'fly': 35,
#          'sticks': 59,
#          'tongue': 98,
#          '.': 13,
#          'make': 55,
#          'faces': 66,
#          'look': 250,
#          'silly': 15,
#          'horse': 229,
#          'sweatshirt': 75,
#          'fire': 108,
#          'barrel': 22,
#          'lead': 16,
#          'horses': 90,
#          'bulldog': 9,
#          'pushing': 58,
#          'anouther': 1,
#          'skinny': 18,
#          'smaller': 62,
#          'int': 6,
#          'various': 19,
#          'sizes': 4,
#          'lady': 219,
#          'no': 78,
#          'dock': 93,
#          'deck': 37,
#          'closeup': 66,
#          'that': 386,
#          'paws': 30,
#          'lying': 95,
#          'resting': 42,
#          'tiled': 9,
#          'eyes': 87,
#          'rests': 23,
#          'patio': 20,
#          'bricks': 4,
#          'artificial': 9,
#          'safety': 31,
#          'harness': 80,
#          'indoor': 43,
#          '"the': 169,
#          'ring': 64,
#          'jumphouse': 1,
#          'teenage': 72,
#          'seating': 6,
#          'inflated': 5,
#          'family': 84,
#          'tractor': 9,
#          'polaris': 3,
#          'vehicle': 76,
#          'played': 18,
#          'wheeler': 12,
#          'riding': 884,
#          'atv': 39,
#          'costume': 128,
#          'left': 80,
#          'sequined': 4,
#          'feather': 10,
#          'sidewalk': 357,
#          'salmon': 2,
#          'bikini': 64,
#          ';': 31,
#          'outfit': 156,
#          'drinking': 92,
#          'pop': 7,
#          'approached': 2,
#          'flamboyant': 3,
#          'dressed': 541,
#          'feathered': 7,
#          'headress': 1,
#          'skiiers': 9,
#          'forest': 156,
#          'skiing': 109,
#          'wooded': 92,
#          'cross-country': 20,
#          'skiers': 36,
#          'woodland': 21,
#          'trail': 142,
#          'woods': 209,
#          'hikers': 35,
#          'pathway': 11,
#          'path': 313,
#          'happily': 26,
#          'energetic': 1,
#          'mother': 39,
#          'boardwalk': 23,
#          'sea': 26,
#          'pier': 33,
#          'evening': 8,
#          'pony': 12,
#          'wintertime': 2,
#          'atop': 35,
#          'draft': 3,
#          'n': 2,
#          'daft': 1,
#          'pull': 32,
#          'cart': 79,
#          'golden': 103,
#          'sleigh': 3,
#          'driven': 10,
#          'coat': 252,
#          'pulling': 108,
#          'carriage': 19,
#          'sled': 114,
#          'steered': 2,
#          'sheer': 16,
#          'using': 58,
#          'rappels': 2,
#          'steep': 61,
#          'incline': 11,
#          'vest': 91,
#          'inside': 168,
#          'dome': 3,
#          'shaft': 1,
#          'cave': 20,
#          'shows': 30,
#          'spelunkers': 2,
#          'cavern': 1,
#          'bathed': 1,
#          'sunlight': 11,
#          'rocks': 249,
#          'backpackers': 2,
#          'lay': 20,
#          'dry': 78,
#          'camp': 6,
#          'gear': 113,
#          'chalk': 15,
#          'portrait': 6,
#          'stream': 111,
#          'drawing': 13,
#          'barn-like': 1,
#          'elaborate': 11,
#          'illustration': 2,
#          'deep': 80,
#          'pile': 75,
#          'fountain': 178,
#          'fountains': 14,
#          'sprayed': 24,
#          'corgi': 4,
#          'tunnel': 66,
#          'course': 131,
#          'obstacle': 122,
#          'obedience': 3,
#          'swimsuit': 61,
#          'handrail': 31,
#          'bathing': 117,
#          'suit': 237,
#          'spray': 34,
#          'soaked': 12,
#          'jet': 21,
#          'sticking': 49,
#          'shower': 20,
#          'gets': 106,
#          'underwater': 52,
#          'red-headed': 4,
#          'swims': 103,
#          'gun': 39,
#          'foot': 38,
#          'aims': 5,
#          'fireplace': 10,
#          'new': 17,
#          'light-up': 1,
#          'pointed': 12,
#          'alone': 34,
#          'jagged': 7,
#          'snowmobile': 13,
#          'mid': 8,
#          'snowmobiler': 2,
#          'flies': 100,
#          'rider': 182,
#          'or': 82,
#          'machine': 30,
#          'pine': 22,
#          'rural': 41,
#          'snowmobiles': 4,
#          'helmets': 35,
#          'goggles': 65,
#          'snowmobiling': 2,
#          'helmeted': 15,
#          'drive': 16,
#          'atvs': 3,
#          'heads': 47,
#          'wheel': 57,
#          'wheelers': 3,
#          'empty': 47,
#          'all': 121,
#          '!': 9,
#          'gin': 1,
#          'four-wheeler': 5,
#          'airborne': 70,
#          'quad': 6,
#          'harvested': 2,
#          'cornfield': 1,
#          's': 2,
#          'happy': 19,
#          'od': 1,
#          'playfully': 31,
#          'soccer': 564,
#          'tucked': 1,
#          't-shirt': 146,
#          'artist': 13,
#          'paints': 12,
#          'clouds': 25,
#          'braids': 6,
#          'colors': 21,
#          'paper': 72,
#          'cyclist': 72,
#          'curved': 4,
#          'aerodynamic': 2,
#          'sharp': 20,
#          'curve': 24,
#          'pedaling': 3,
#          '"man': 27,
#          'biker': 171,
#          'fetch': 31,
#          'pounces': 7,
#          'cine': 1,
#          'old': 170,
#          'fashioned': 6,
#          'video': 39,
#          'steadies': 2,
#          'aim': 4,
#          'rosy': 1,
#          'cheeks': 6,
#          'lips': 17,
#          'border': 9,
#          'collie': 30,
#          'audience': 36,
#          'dug': 3,
#          'agile': 1,
#          'onlookers': 47,
#          'closely': 5,
#          'smooth': 6,
#          'stacking': 1,
#          'against': 193,
#          'backdrop': 9,
#          'shoes': 81,
#          'rappeling': 1,
#          'headlamp': 2,
#          'attached': 51,
#          'snakeskin': 1,
#          'sprays': 11,
#          'frog': 5,
#          'public': 47,
#          'wood': 69,
#          'barrior': 1,
#          'animal': 92,
#          'bird': 186,
#          'seeds': 6,
#          'sunflower': 1,
#          'clinging': 5,
#          'finger': 31,
#          'wades': 12,
#          'guided': 3,
#          'laughs': 32,
#          'playful': 7,
#          'beige': 51,
#          'torwards': 1,
#          'outdoor': 127,
#          'handstand': 48,
#          'does': 226,
#          'sheets': 5,
#          'upside': 89,
#          'snowboard': 87,
#          'surfboard': 146,
#          'bikes': 83,
#          'traveling': 16,
#          'worn': 5,
#          'motorcycles': 27,
#          'motorbikes': 7,
#          'follow': 14,
#          'dirt-bikes': 1,
#          'off-road': 9,
#          'garment': 1,
#          'flag': 91,
#          'crescent': 1,
#          'moon': 3,
#          'star': 11,
#          'gown': 9,
#          'muslim': 3,
#          'helps': 29,
#          'wave': 314,
#          'half': 29,
#          'naked': 47,
#          'chair': 125,
#          'older': 206,
#          'back': 354,
#          'relaxes': 12,
#          'adobe': 1,
#          'where': 37,
#          'bicycles': 52,
#          'propped': 4,
#          'cap': 170,
#          'relaxing': 15,
#          'folding': 10,
#          '"topless': 2,
#          'slippers': 2,
#          'hauling': 1,
#          'retrieve': 9,
#          'mouths': 37,
#          'tug': 29,
#          'chew': 16,
#          '"there': 43,
#          'party': 55,
#          'streets': 28,
#          'drink': 101,
#          'they': 117,
#          'women': 639,
#          'parade': 63,
#          'neck-deep': 1,
#          '"brown': 14,
#          'creating': 8,
#          'splash': 42,
#          'seaweed': 10,
#          'lav': 1,
#          'sandals': 17,
#          'pinstripe': 2,
#          'snows': 4,
#          'furry': 52,
#          'attempts': 52,
#          'itself': 19,
#          'shaking': 67,
#          'self': 5,
#          'backpacks': 29,
#          'placed': 9,
#          'cardboard': 24,
#          'bus': 74,
#          'station': 32,
#          'bouncing': 28,
#          'folded': 8,
#          'beds': 3,
#          'bedroom': 5,
#          'snowboarder': 236,
#          'slope': 72,
#          'boarders': 1,
#          'snowboarders': 12,
#          'clothing': 122,
#          'store': 105,
#          'opening': 13,
#          'stores': 8,
#          'piece': 63,
#          'attire': 25,
#          'car': 419,
#          'strip': 22,
#          'boots': 55,
#          'stepping': 8,
#          'van': 16,
#          'wear': 47,
#          'game': 359,
#          'plants': 38,
#          'crossing': 57,
#          'greenery': 6,
#          'suspension': 1,
#          'tropical': 12,
#          'caution': 6,
#          'sign': 234,
#          'beside': 243,
#          'bright': 120,
#          'truck': 87,
#          'others': 147,
#          'watch': 220,
#          'helping': 27,
#          'step': 29,
#          'pulled': 39,
#          'passengers': 7,
#          'load': 2,
#          'brightly': 30,
#          'poses': 140,
#          'pig': 5,
#          'hugs': 23,
#          'who': 206,
#          '"blond': 4,
#          'embracing': 8,
#          'hugging': 57,
#          'pink-hooded': 1,
#          'stretch': 11,
#          'bicyclist': 63,
#          'cross': 44,
#          'spandex': 2,
#          'biking': 28,
#          'jogging': 25,
#          'headset': 5,
#          'walkman': 1,
#          'jogs': 13,
#          'headphones': 38,
#          'plant': 16,
#          'corner': 57,
#          'bicyclists': 24,
#          'intersection': 14,
#          'bikers': 29,
#          'stop': 34,
#          'town': 24,
#          'without': 25,
#          'guiding': 5,
#          'wagon': 25,
#          'escorts': 1,
#          'leading': 20,
#          'horse-drawn': 1,
#          'shetland': 1,
#          'hits': 48,
#          'tee': 6,
#          'practices': 10,
#          'hitting': 35,
#          'baseball': 285,
#          'bats': 3,
#          'put': 24,
#          'batting': 7,
#          'cage': 14,
#          'spins': 15,
#          'sun': 98,
#          'she': 88,
#          'trumpet': 8,
#          ...})

# %%
#Visualise the top 30 occuring words in the captions
for word, count in val_count.most_common(30):
  print(word, ": ", count)

lst = val_count.most_common(30)
most_common_words_df = pd.DataFrame(lst, columns = ['Word', 'Count'])
most_common_words_df.plot.bar(x='Word', y='Count', width=0.6, color='orange', figsize=(15, 10))
plt.title("Top 30 maximum frequency words", fontsize = 18, color= 'navy')
plt.xlabel("Words", fontsize = 14, color= 'navy')
plt.ylabel("Count", fontsize = 14, color= 'navy')
# Out:
# a :  60196
# in :  18174
# the :  17507
# on :  10357
# is :  9069
# and :  8057
# dog :  7948
# with :  7304
# man :  7137
# of :  6495
# two :  5132
# white :  3706
# black :  3620
# boy :  3514
# are :  3365
# woman :  3304
# girl :  3277
# to :  3005
# wearing :  2916
# people :  2811
# at :  2810
# water :  2676
# young :  2587
# red :  2553
# brown :  2457
# an :  2325
# his :  2255
# blue :  2125
# dogs :  2095
# running :  1996
# Text(0, 0.5, 'Count')

# %%
wordcloud = WordCloud(width = 1000, height = 500).generate_from_frequencies(val_count)
plt.figure(figsize = (12, 12))
plt.imshow(wordcloud)

# %%
def caption_with_img_plot(image_id, frame) :
  capt = ("\n" *2).join(frame[frame['ID'] == image_id].Captions.to_list())
  fig, ax = plt.subplots()
  ax.set_axis_off()
  idx = df.ID.to_list().index(image_id)
  im =  Image.open(df.Path.iloc[idx])
  w, h = im.size[0], im.size[-1]
  ax.imshow(im)
  ax.text(w+50, h, capt, fontsize = 18, color = 'navy')
caption_with_img_plot(df.ID.iloc[7049], df)

# %% [markdown]
# ## Data Cleaning

# %%
#data cleaning
rem_punct = str.maketrans('', '', string.punctuation)
for r in range(len(annotations)) :
  line = annotations[r]
  line = line.split()

  # converting to lowercase
  line = [word.lower() for word in line]

  # remove punctuation from each caption and hanging letters
  line = [word.translate(rem_punct) for word in line]
  line = [word for word in line if len(word) > 1]

  # remove numeric values
  line = [word for word in line if word.isalpha()]

  annotations[r] = ' '.join(line)

# %%
#add the <start> & <end> token to all those captions as well
annotations = ['<start>' + ' ' + line + ' ' + '<end>' for line in annotations]

#Create a list which contains all the path to the images
all_img_path = all_img_vector

# %%
##list contatining captions for an image
annotations[0:5]
# Out:
# ['<start> child in pink dress is climbing up set of stairs in an entry way <end>',
#  '<start> girl going into wooden building <end>',
#  '<start> little girl climbing into wooden playhouse <end>',
#  '<start> little girl climbing the stairs to her playhouse <end>',
#  '<start> little girl in pink dress going into wooden cabin <end>']

# %% [markdown]
# ## Data Preprocessing

# %%
# Creating the tokenizer
top_word_cnt = 5000
tokenizer = Tokenizer(num_words = top_word_cnt+1, filters= '!"#$%^&*()_+.,:;-?/~`{}[]|\=@ ',
                      lower = True, char_level = False, 
                      oov_token = 'UNK')

# %%
# Creating word-to-index and index-to-word mappings.

tokenizer.fit_on_texts(annotations)
#transform each text into a sequence of integers
train_seqs = tokenizer.texts_to_sequences(annotations)

# %%
# We add PAD token for zero
tokenizer.word_index['PAD'] = 0
tokenizer.index_word[0] = 'PAD'

# %%
print(tokenizer.oov_token)
print(tokenizer.index_word[0])
# Out:
# UNK
# PAD

# %%
tokenizer.index_word
# Out:
# {1: 'UNK',
#  2: '<start>',
#  3: '<end>',
#  4: 'in',
#  5: 'the',
#  6: 'on',
#  7: 'is',
#  8: 'and',
#  9: 'dog',
#  10: 'with',
#  11: 'man',
#  12: 'of',
#  13: 'two',
#  14: 'white',
#  15: 'black',
#  16: 'boy',
#  17: 'are',
#  18: 'woman',
#  19: 'girl',
#  20: 'to',
#  21: 'wearing',
#  22: 'people',
#  23: 'at',
#  24: 'water',
#  25: 'young',
#  26: 'red',
#  27: 'brown',
#  28: 'an',
#  29: 'his',
#  30: 'blue',
#  31: 'dogs',
#  32: 'running',
#  33: 'through',
#  34: 'playing',
#  35: 'while',
#  36: 'down',
#  37: 'little',
#  38: 'shirt',
#  39: 'standing',
#  40: 'ball',
#  41: 'grass',
#  42: 'person',
#  43: 'child',
#  44: 'snow',
#  45: 'jumping',
#  46: 'over',
#  47: 'three',
#  48: 'front',
#  49: 'sitting',
#  50: 'small',
#  51: 'field',
#  52: 'up',
#  53: 'holding',
#  54: 'large',
#  55: 'group',
#  56: 'by',
#  57: 'green',
#  58: 'yellow',
#  59: 'children',
#  60: 'walking',
#  61: 'men',
#  62: 'her',
#  63: 'into',
#  64: 'beach',
#  65: 'air',
#  66: 'near',
#  67: 'jumps',
#  68: 'mouth',
#  69: 'street',
#  70: 'runs',
#  71: 'for',
#  72: 'another',
#  73: 'riding',
#  74: 'from',
#  75: 'its',
#  76: 'as',
#  77: 'bike',
#  78: 'stands',
#  79: 'girls',
#  80: 'one',
#  81: 'outside',
#  82: 'rock',
#  83: 'player',
#  84: 'off',
#  85: 'next',
#  86: 'play',
#  87: 'out',
#  88: 'pink',
#  89: 'orange',
#  90: 'looking',
#  91: 'pool',
#  92: 'other',
#  93: 'their',
#  94: 'camera',
#  95: 'boys',
#  96: 'jacket',
#  97: 'women',
#  98: 'hat',
#  99: 'around',
#  100: 'some',
#  101: 'dirt',
#  102: 'soccer',
#  103: 'sits',
#  104: 'behind',
#  105: 'toy',
#  106: 'dressed',
#  107: 'mountain',
#  108: 'wall',
#  109: 'walks',
#  110: 'has',
#  111: 'plays',
#  112: 'along',
#  113: 'stand',
#  114: 'crowd',
#  115: 'climbing',
#  116: 'looks',
#  117: 'park',
#  118: 'four',
#  119: 'building',
#  120: 'football',
#  121: 'across',
#  122: 'top',
#  123: 'holds',
#  124: 'rides',
#  125: 'ocean',
#  126: 'grassy',
#  127: 'sand',
#  128: 'face',
#  129: 'background',
#  130: 'smiling',
#  131: 'stick',
#  132: 'swimming',
#  133: 'hill',
#  134: 'skateboard',
#  135: 'car',
#  136: 'doing',
#  137: 'baby',
#  138: 'tennis',
#  139: 'bicycle',
#  140: 'picture',
#  141: 'together',
#  142: 'snowy',
#  143: 'each',
#  144: 'carrying',
#  145: 'jump',
#  146: 'tree',
#  147: 'basketball',
#  148: 'that',
#  149: 'hair',
#  150: 'tan',
#  151: 'road',
#  152: 'trick',
#  153: 'race',
#  154: 'it',
#  155: 'area',
#  156: 'swing',
#  157: 'bench',
#  158: 'game',
#  159: 'head',
#  160: 'sidewalk',
#  161: 'catch',
#  162: 'back',
#  163: 'him',
#  164: 'shorts',
#  165: 'sit',
#  166: 'run',
#  167: 'kids',
#  168: 'helmet',
#  169: 'dress',
#  170: 'ground',
#  171: 'something',
#  172: 'being',
#  173: 'frisbee',
#  174: 'fence',
#  175: 'lake',
#  176: 'hand',
#  177: 'wave',
#  178: 'skateboarder',
#  179: 'path',
#  180: 'ramp',
#  181: 'several',
#  182: 'city',
#  183: 'purple',
#  184: 'walk',
#  185: 'there',
#  186: 'slide',
#  187: 'covered',
#  188: 'side',
#  189: 'baseball',
#  190: 'players',
#  191: 'posing',
#  192: 'track',
#  193: 'wooden',
#  194: 'high',
#  195: 'long',
#  196: 'big',
#  197: 'boat',
#  198: 'sunglasses',
#  199: 'watches',
#  200: 'uniform',
#  201: 'coat',
#  202: 'look',
#  203: 'rocks',
#  204: 'ride',
#  205: 'trees',
#  206: 'table',
#  207: 'motorcycle',
#  208: 'couple',
#  209: 'beside',
#  210: 'snowboarder',
#  211: 'rope',
#  212: 'watching',
#  213: 'under',
#  214: 'suit',
#  215: 'towards',
#  216: 'pants',
#  217: 'dark',
#  218: 'sign',
#  219: 'grey',
#  220: 'rocky',
#  221: 'hands',
#  222: 'river',
#  223: 'horse',
#  224: 'does',
#  225: 'arms',
#  226: 'racing',
#  227: 'lady',
#  228: 'watch',
#  229: 'ice',
#  230: 'them',
#  231: 'older',
#  232: 'above',
#  233: 'colorful',
#  234: 'woods',
#  235: 'pose',
#  236: 'jeans',
#  237: 'guy',
#  238: 'who',
#  239: 'midair',
#  240: 'onto',
#  241: 'he',
#  242: 'striped',
#  243: 'asian',
#  244: 'leaps',
#  245: 'playground',
#  246: 'climbs',
#  247: 'hockey',
#  248: 'performing',
#  249: 'taking',
#  250: 'cliff',
#  251: 'mountains',
#  252: 'yard',
#  253: 'collar',
#  254: 'against',
#  255: 'blonde',
#  256: 'surfer',
#  257: 'bird',
#  258: 'body',
#  259: 'blond',
#  260: 'glasses',
#  261: 'smiles',
#  262: 'laying',
#  263: 'kid',
#  264: 'rider',
#  265: 'chasing',
#  266: 'skier',
#  267: 'many',
#  268: 'team',
#  269: 'fountain',
#  270: 'after',
#  271: 'during',
#  272: 'biker',
#  273: 'wet',
#  274: 'old',
#  275: 'cap',
#  276: 'inside',
#  277: 'toddler',
#  278: 'takes',
#  279: 'open',
#  280: 'brick',
#  281: 'edge',
#  282: 'flying',
#  283: 'very',
#  284: 'colored',
#  285: 'someone',
#  286: 'guitar',
#  287: 'shore',
#  288: 'trying',
#  289: 'outdoors',
#  290: 'outfit',
#  291: 'forest',
#  292: 'five',
#  293: 'surrounded',
#  294: 'middle',
#  295: 'hanging',
#  296: 'night',
#  297: 'away',
#  298: 'bed',
#  299: 'light',
#  300: 'talking',
#  301: 'pole',
#  302: 'whilst',
#  303: 'others',
#  304: 'object',
#  305: 'floor',
#  306: 'tshirt',
#  307: 'surfboard',
#  308: 'steps',
#  309: 'going',
#  310: 'past',
#  311: 'line',
#  312: 'backpack',
#  313: 'toward',
#  314: 'about',
#  315: 'making',
#  316: 'trail',
#  317: 'swinging',
#  318: 'this',
#  319: 'eating',
#  320: 'nearby',
#  321: 'poses',
#  322: 'haired',
#  323: 'gray',
#  324: 'tall',
#  325: 'arm',
#  326: 'dancing',
#  327: 'flowers',
#  328: 'bridge',
#  329: 'day',
#  330: 'waves',
#  331: 'leaves',
#  332: 'clothes',
#  333: 'course',
#  334: 'fighting',
#  335: 'leaping',
#  336: 'sky',
#  337: 'board',
#  338: 'shallow',
#  339: 'window',
#  340: 'costume',
#  341: 'outdoor',
#  342: 'plastic',
#  343: 'carries',
#  344: 'house',
#  345: 'leash',
#  346: 'splashing',
#  347: 'room',
#  348: 'chair',
#  349: 'legs',
#  350: 'climber',
#  351: 'bag',
#  352: 'stone',
#  353: 'catches',
#  354: 'obstacle',
#  355: 'clothing',
#  356: 'all',
#  357: 'bright',
#  358: 'swings',
#  359: 'ready',
#  360: 'between',
#  361: 'getting',
#  362: 'skateboarding',
#  363: 'they',
#  364: 'sliding',
#  365: 'bathing',
#  366: 'sweater',
#  367: 'trampoline',
#  368: 'sled',
#  369: 'gear',
#  370: 'concrete',
#  371: 'adult',
#  372: 'railing',
#  373: 'wears',
#  374: 'mud',
#  375: 'waiting',
#  376: 'skiing',
#  377: 'stream',
#  378: 'metal',
#  379: 'lawn',
#  380: 'male',
#  381: 'winter',
#  382: 'stairs',
#  383: 'fire',
#  384: 'pulling',
#  385: 'uniforms',
#  386: 'shirts',
#  387: 'sandy',
#  388: 'catching',
#  389: 'gets',
#  390: 'set',
#  391: 'store',
#  392: 'jersey',
#  393: 'tries',
#  394: 'train',
#  395: 'lot',
#  396: 'golden',
#  397: 'swims',
#  398: 'bar',
#  399: 'adults',
#  400: 'fishing',
#  401: 'rail',
#  402: 'drink',
#  403: 'tricks',
#  404: 'shirtless',
#  405: 'get',
#  406: 'flies',
#  407: 'female',
#  408: 'smile',
#  409: 'distance',
#  410: 'overlooking',
#  411: 'couch',
#  412: 'busy',
#  413: 'tongue',
#  414: 'sun',
#  415: 'makes',
#  416: 'chases',
#  417: 'performs',
#  418: 'throwing',
#  419: 'surfing',
#  420: 'trunks',
#  421: 'ski',
#  422: 'lying',
#  423: 'number',
#  424: 'puppy',
#  425: 'puddle',
#  426: 'dock',
#  427: 'huge',
#  428: 'pond',
#  429: 'swim',
#  430: 'drinking',
#  431: 'wooded',
#  432: 'animal',
#  433: 'vest',
#  434: 'flag',
#  435: 'tire',
#  436: 'horses',
#  437: 'bubbles',
#  438: 'upside',
#  439: 'photo',
#  440: 'leaning',
#  441: 'cellphone',
#  442: 'slides',
#  443: 'she',
#  444: 'kayak',
#  445: 'eyes',
#  446: 'snowboard',
#  447: 'truck',
#  448: 'flip',
#  449: 'laughing',
#  450: 'nose',
#  451: 'sunset',
#  452: 'shopping',
#  453: 'waterfall',
#  454: 'right',
#  455: 'american',
#  456: 'equipment',
#  457: 'reading',
#  458: 'view',
#  459: 'wetsuit',
#  460: 'family',
#  461: 'hold',
#  462: 'bat',
#  463: 'greyhound',
#  464: 'stunt',
#  465: 'food',
#  466: 'bikes',
#  467: 'elderly',
#  468: 'hats',
#  469: 'climb',
#  470: 'restaurant',
#  471: 'lone',
#  472: 'life',
#  473: 'or',
#  474: 'coming',
#  475: 'hurdle',
#  476: 'skis',
#  477: 'goal',
#  478: 'shoes',
#  479: 'like',
#  480: 'hiker',
#  481: 'harness',
#  482: 'left',
#  483: 'deep',
#  484: 'skating',
#  485: 'feet',
#  486: 'tent',
#  487: 'biting',
#  488: 'cart',
#  489: 'scarf',
#  490: 'setting',
#  491: 'no',
#  492: 'dry',
#  493: 'mask',
#  494: 'muddy',
#  495: 'guys',
#  496: 'take',
#  497: 'bmx',
#  498: 'closeup',
#  499: 'court',
#  500: 'fight',
#  501: 'vehicle',
#  502: 'umbrella',
#  503: 'six',
#  504: 'crowded',
#  505: 'sweatshirt',
#  506: 'pile',
#  507: 'skate',
#  508: 'dresses',
#  509: 'raft',
#  510: 'falling',
#  511: 'bus',
#  512: 'german',
#  513: 'structure',
#  514: 'ledge',
#  515: 'have',
#  516: 'diving',
#  517: 'tank',
#  518: 'driving',
#  519: 'surf',
#  520: 'teenage',
#  521: 'paper',
#  522: 'cyclist',
#  523: 'slope',
#  524: 'cement',
#  525: 'bags',
#  526: 'canoe',
#  527: 'inflatable',
#  528: 'airborne',
#  529: 'flags',
#  530: 'be',
#  531: 'cigarette',
#  532: 'book',
#  533: 'subway',
#  534: 'skirt',
#  535: 'goes',
#  536: 'splashes',
#  537: 'turn',
#  538: 'wood',
#  539: 'kick',
#  540: 'costumes',
#  541: 'shepherd',
#  542: 'fallen',
#  543: 'jackets',
#  544: 'shaking',
#  545: 'dance',
#  546: 'kicking',
#  547: 'bottle',
#  548: 'buildings',
#  549: 'both',
#  550: 'parking',
#  551: 'faces',
#  552: 'tunnel',
#  553: 'sports',
#  554: 'ears',
#  555: 'gathered',
#  556: 'goggles',
#  557: 'band',
#  558: 'hit',
#  559: 'balls',
#  560: 'microphone',
#  561: 'ring',
#  562: 'bikini',
#  563: 'parade',
#  564: 'chairs',
#  565: 'throws',
#  566: 'kicks',
#  567: 'pictures',
#  568: 'piece',
#  569: 'bicyclist',
#  570: 'full',
#  571: 'hiking',
#  572: 'beard',
#  573: 'stage',
#  574: 'bull',
#  575: 'rugby',
#  576: 'painted',
#  577: 'backyard',
#  578: 'smaller',
#  579: 'blanket',
#  580: 'silver',
#  581: 'outfits',
#  582: 'event',
#  583: 'blowing',
#  584: 'cars',
#  585: 'sunny',
#  586: 'steep',
#  587: 'swimsuit',
#  588: 'cat',
#  589: 'box',
#  590: 'leather',
#  591: 'surface',
#  592: 'statue',
#  593: 'low',
#  594: 'drinks',
#  595: 'scooter',
#  596: 'short',
#  597: 'glass',
#  598: 'sticks',
#  599: 'stuffed',
#  600: 'bald',
#  601: 'suits',
#  602: 'held',
#  603: 'volleyball',
#  604: 'graffiti',
#  605: 'smoking',
#  606: 'sleeping',
#  607: 'pushing',
#  608: 'using',
#  609: 'wrestling',
#  610: 'throw',
#  611: 'pointing',
#  612: 'cow',
#  613: 'staring',
#  614: 'paint',
#  615: 'net',
#  616: 'leans',
#  617: 'wheel',
#  618: 'crossing',
#  619: 'hugging',
#  620: 'corner',
#  621: 'fluffy',
#  622: 'tube',
#  623: 'door',
#  624: 'attempting',
#  625: 'few',
#  626: 'bucket',
#  627: 'hind',
#  628: 'motorcyclist',
#  629: 'lays',
#  630: 'make',
#  631: 'party',
#  632: 'boots',
#  633: 'wrestle',
#  634: 'flower',
#  635: 'hangs',
#  636: 'puppies',
#  637: 'show',
#  638: 'bunch',
#  639: 'same',
#  640: 'police',
#  641: 'snowboarding',
#  642: 'cowboy',
#  643: 'log',
#  644: 'beautiful',
#  645: 'wading',
#  646: 'cup',
#  647: 'teams',
#  648: 'sheep',
#  649: 'leg',
#  650: 'competition',
#  651: 'sprinkler',
#  652: 'eats',
#  653: 'fast',
#  654: 'underwater',
#  655: 'bicycles',
#  656: 'furry',
#  657: 'attempts',
#  658: 'spectators',
#  659: 'softball',
#  660: 'gather',
#  661: 'racetrack',
#  662: 'garden',
#  663: 'attached',
#  664: 'beige',
#  665: 'dances',
#  666: 'fish',
#  667: 'gym',
#  668: 'go',
#  669: 'kissing',
#  670: 'hoop',
#  671: 'desert',
#  672: 'end',
#  673: 'motocross',
#  674: 'racer',
#  675: 'phone',
#  676: 'poles',
#  677: 'shot',
#  678: 'racket',
#  679: 'below',
#  680: 'seat',
#  681: 'sticking',
#  682: 'handstand',
#  683: 'clear',
#  684: 'pushes',
#  685: 'rolling',
#  686: 'points',
#  687: 'way',
#  688: 'prepares',
#  689: 'platform',
#  690: 'toys',
#  691: 'empty',
#  692: 'onlookers',
#  693: 'hits',
#  694: 'wide',
#  695: 'talks',
#  696: 'rain',
#  697: 'gravel',
#  698: 'shop',
#  699: 'gold',
#  700: 'do',
#  701: 'signs',
#  702: 'bride',
#  703: 'paddling',
#  704: 'waving',
#  705: 'snowcovered',
#  706: 'heads',
#  707: 'public',
#  708: 'naked',
#  709: 'wear',
#  710: 'rough',
#  711: 'just',
#  712: 'ladies',
#  713: 'among',
#  714: 'base',
#  715: 'mohawk',
#  716: 'market',
#  717: 'headband',
#  718: 'birds',
#  719: 'pavement',
#  720: 'facing',
#  721: 'reads',
#  722: 'having',
#  723: 'traffic',
#  724: 'plaid',
#  725: 'branch',
#  726: 'neck',
#  727: 'downhill',
#  728: 'skateboards',
#  729: 'cream',
#  730: 'african',
#  731: 'hose',
#  732: 'thrown',
#  733: 'cross',
#  734: 'drives',
#  735: 'dirty',
#  736: 'bars',
#  737: 'wings',
#  738: 'scene',
#  739: 'bottom',
#  740: 'fenced',
#  741: 'races',
#  742: 'different',
#  743: 'painting',
#  744: 'lies',
#  745: 'beer',
#  746: 'wait',
#  747: 'indoor',
#  748: 'barefoot',
#  749: 'chewing',
#  750: 'cricket',
#  751: 'goalie',
#  752: 'resting',
#  753: 'splash',
#  754: 'carpet',
#  755: 'says',
#  756: 'waits',
#  757: 'fall',
#  758: 'bearded',
#  759: 'carnival',
#  760: 'kitchen',
#  761: 'school',
#  762: 'rapids',
#  763: 'blows',
#  764: 'wedding',
#  765: 'wrestler',
#  766: 'match',
#  767: 'paved',
#  768: 'balloon',
#  769: 'lit',
#  770: 'rural',
#  771: 'creek',
#  772: 'teeth',
#  773: 'onstage',
#  774: 'stadium',
#  775: 'opposing',
#  776: 'moving',
#  777: 'paddle',
#  778: 'mother',
#  779: 'display',
#  780: 'lap',
#  781: 'younger',
#  782: 'filled',
#  783: 'greyhounds',
#  784: 'santa',
#  785: 'smoke',
#  786: 'hula',
#  787: 'landscape',
#  788: 'atv',
#  789: 'gun',
#  790: 'video',
#  791: 'pulled',
#  792: 'animals',
#  793: 'motorbike',
#  794: 'talk',
#  795: 'shoulder',
#  796: 'showing',
#  797: 'before',
#  798: 'skates',
#  799: 'falls',
#  800: 'shooting',
#  801: 'art',
#  802: 'boats',
#  803: 'foot',
#  804: 'plants',
#  805: 'headphones',
#  806: 'chase',
#  807: 'matching',
#  808: 'reaching',
#  809: 'block',
#  810: 'gloves',
#  811: 'hay',
#  812: 'staircase',
#  813: 'can',
#  814: 'ropes',
#  815: 'floating',
#  816: 'deck',
#  817: 'where',
#  818: 'mouths',
#  819: 'fair',
#  820: 'try',
#  821: 'unicycle',
#  822: 'reaches',
#  823: 'pipe',
#  824: 'wire',
#  825: 'seated',
#  826: 'retriever',
#  827: 'urban',
#  828: 'parked',
#  829: 'pack',
#  830: 'martial',
#  831: 'close',
#  832: 'instruments',
#  833: 'singing',
#  834: 'bubble',
#  835: 'runner',
#  836: 'teenagers',
#  837: 'christmas',
#  838: 'spotted',
#  839: 'shakes',
#  840: 'skiers',
#  841: 'audience',
#  842: 'amusement',
#  843: 'poodle',
#  844: 'formation',
#  845: 'bandanna',
#  846: 'pulls',
#  847: 'multicolored',
#  848: 'wheelie',
#  849: 'digging',
#  850: 'lights',
#  851: 'surfs',
#  852: 'grinding',
#  853: 'flight',
#  854: 'duck',
#  855: 'hole',
#  856: 'outstretched',
#  857: 'lined',
#  858: 'fly',
#  859: 'hikers',
#  860: 'atop',
#  861: 'helmets',
#  862: 'hitting',
#  863: 'purse',
#  864: 'follows',
#  865: 'funny',
#  866: 'shoulders',
#  867: 'kite',
#  868: 'covering',
#  869: 'raises',
#  870: 'perform',
#  871: 'giant',
#  872: 'row',
#  873: 'newspaper',
#  874: 'puts',
#  875: 'spray',
#  876: 'alone',
#  877: 'stop',
#  878: 'preparing',
#  879: 'bank',
#  880: 'photograph',
#  881: 'ear',
#  882: 'enjoys',
#  883: 'bushes',
#  884: 'hoodie',
#  885: 'balancing',
#  886: 'curly',
#  887: 'muzzled',
#  888: 'rodeo',
#  889: 'jumped',
#  890: 'rowing',
#  891: 'kneeling',
#  892: 'paddles',
#  893: 'pier',
#  894: 'alongside',
#  895: 'backwards',
#  896: 'music',
#  897: 'jeep',
#  898: 'parachute',
#  899: 'muzzle',
#  900: 'putting',
#  901: 'hang',
#  902: 'pull',
#  903: 'laughs',
#  904: 'station',
#  905: 'giving',
#  906: 'writing',
#  907: 'gives',
#  908: 'cold',
#  909: 'tie',
#  910: 'denim',
#  911: 'owner',
#  912: 'indoors',
#  913: 'spinning',
#  914: 'plate',
#  915: 'himself',
#  916: 'gate',
#  917: 'bite',
#  918: 'chain',
#  919: 'riders',
#  920: 'bites',
#  921: 'break',
#  922: 'appears',
#  923: 'safety',
#  924: 'handrail',
#  925: 'playfully',
#  926: 'fetch',
#  927: 'finger',
#  928: 'brightly',
#  929: 'bikers',
#  930: 'picnic',
#  931: 'makeup',
#  932: 'underneath',
#  933: 'competing',
#  934: 'mound',
#  935: 'licking',
#  936: 'tackle',
#  937: 'terrier',
#  938: 'seven',
#  939: 'rink',
#  940: 'construction',
#  941: 'paws',
#  942: 'shows',
#  943: 'machine',
#  944: 'collie',
#  945: 'these',
#  946: 'shaggy',
#  947: 'foreground',
#  948: 'ladder',
#  949: 'hillside',
#  950: 'referee',
#  951: 'enjoying',
#  952: 'roller',
#  953: 'necklace',
#  954: 'backs',
#  955: 'larger',
#  956: 'professional',
#  957: 'doorway',
#  958: 'passing',
#  959: 'bowl',
#  960: 'waters',
#  961: 'kayaking',
#  962: 'terrain',
#  963: 'quickly',
#  964: 'helps',
#  965: 'half',
#  966: 'tug',
#  967: 'backpacks',
#  968: 'step',
#  969: 'hooded',
#  970: 'float',
#  971: 'splashed',
#  972: 'jungle',
#  973: 'taken',
#  974: 'balances',
#  975: 'made',
#  976: 'lean',
#  977: 'skater',
#  978: 'third',
#  979: 'counter',
#  980: 'homeless',
#  981: 'sniffing',
#  982: 'shadow',
#  983: 'hoops',
#  984: 'caught',
#  985: 'friend',
#  986: 'pigeons',
#  987: 'violin',
#  988: 'fingers',
#  989: 'military',
#  990: 'wheelchair',
#  991: 'basket',
#  992: 'round',
#  993: 'spots',
#  994: 'courtyard',
#  995: 'crouches',
#  996: 'streets',
#  997: 'bouncing',
#  998: 'biking',
#  999: 'leap',
#  1000: 'straw',
#  ...}

# %%
# Creating a word count for our tokenizer to visualize the Top 30 occuring words after text processing

tokenizer_top_words = [word for line in annotations for word in line.split() ]

#tokenizer_top_words_count
tokenizer_top_words_count = collections.Counter(tokenizer_top_words)

# %%
for word, count in tokenizer_top_words_count.most_common(30) :
  print(word, ": ", count)

tokens = tokenizer_top_words_count.most_common(30)
most_com_words_df = pd.DataFrame(tokens, columns = ['Word', 'Count'])

#plot 30 most common words
most_common_words_df.plot.bar(x = 'Word', y= 'Count', width=0.8, color = 'indigo', figsize = (17, 10))
plt.title('Top 30 common words', fontsize =20, color= 'navy')
plt.xlabel('Words', fontsize =14, color= 'navy')
plt.ylabel('Counts', fontsize =14, color= 'navy')
plt.grid(b=None)
# Out:
# <start> :  40455
# <end> :  40455
# in :  18182
# the :  17676
# on :  10367
# is :  9069
# and :  8057
# dog :  7956
# with :  7308
# man :  7164
# of :  6496
# two :  5546
# white :  3710
# black :  3627
# boy :  3534
# are :  3365
# woman :  3320
# girl :  3284
# to :  3005
# wearing :  2917
# people :  2837
# at :  2819
# water :  2676
# young :  2610
# red :  2553
# brown :  2471
# an :  2358
# his :  2255
# blue :  2125
# dogs :  2097

# %%
wordcloud_token = WordCloud(width = 1000, height = 500).generate_from_frequencies(tokenizer_top_words_count)
plt.figure(figsize = (12, 8))
plt.imshow(wordcloud_token)
plt.grid(b = None)

# %%
# Pad each vector to the max_length of the captions  store it to a vairable

train_seqs_len = [len(seq) for seq in train_seqs]

longest_word_length = max(train_seqs_len)

cap_vector= tf.keras.preprocessing.sequence.pad_sequences(train_seqs, padding= 'post', maxlen = longest_word_length,
                                                          dtype='int32', value=0)
print("Caption length:" + str(cap_vector.shape))
# Out:
# Caption length:(40455, 31)

# %%
# creating list to store preprocessed images and setting up the Image Shape

preprocessed_image = []
IMAGE_SHAPE = (299, 299)

# %%
#checking image format 

tf.keras.backend.image_data_format()
# Out:
# 'channels_last'

# %%
for img in all_imgs[0:5] :
    img = tf.io.read_file(img, name=None)
    img = tf.image.decode_jpeg(img, channels=0)
    img = tf.image.resize(img, (299, 299))
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    preprocessed_image.append(img)

# %%
# checking first five images post preprocessing
Display_Images = preprocessed_image[0:5]
figure, axes = plt.subplots(1,5)
figure.set_figwidth(25)
for ax, image in zip(axes, Display_Images) :
  print('Shape after resize : ', image.shape)
  ax.imshow(image)
  ax.grid('off')
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Shape after resize :  (299, 299, 3)
# Shape after resize :  (299, 299, 3)
# Shape after resize :  (299, 299, 3)
# Shape after resize :  (299, 299, 3)
# Shape after resize :  (299, 299, 3)

# %% [markdown]
# ## Prepare for training and testing

# %%
def load_images(image_path) :
  img = tf.io.read_file(image_path, name = None)
  img = tf.image.decode_jpeg(img, channels=0)
  img = tf.image.resize(img, IMAGE_SHAPE)
  img = tf.keras.applications.inception_v3.preprocess_input(img)
  return img, image_path

# %%
# Map each image full path to the function, in order to preprocess the image
training_list = sorted(set(all_img_vector))
New_Img = tf.data.Dataset.from_tensor_slices(training_list)
New_Img = New_Img.map(load_images, num_parallel_calls = tf.data.experimental.AUTOTUNE)
New_Img = New_Img.batch(64, drop_remainder=False)

# %%
#Ratio = 80:20 and we will set random state = 42
path_train, path_test, caption_train, caption_test = train_test_split(all_img_vector, cap_vector, test_size = 0.2, random_state = 42)

# %%
print("Training data for images: " + str(len(path_train)))
print("Testing data for images: " + str(len(path_test)))
print("Training data for Captions: " + str(len(caption_train)))
print("Testing data for Captions: " + str(len(caption_test)))
# Out:
# Training data for images: 32364
# Testing data for images: 8091
# Training data for Captions: 32364
# Testing data for Captions: 8091
